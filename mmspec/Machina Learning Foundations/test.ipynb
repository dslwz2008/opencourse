# %%
import graphlab

# %%
sales=graphlab.SFrame('home_data.gl/')
sales
# Out:
# [INFO] 1449542172 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to d:\Anaconda2\lib\site-packages\certifi\cacert.pem
# 1449542172 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to shenshen@radi.ac.cn and will expire on December 04, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-6560 - Server binary: d:\Anaconda2\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\ADMINI~1\AppData\Local\Temp\graphlab_server_1449542173.log.0
# [INFO] GraphLab Server Version: 1.7.1
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# ...

# %%
graphlab.canvas.set_target('ipynb')
sales.show(view="Scatter Plot",x="sqft_living",y="221900")

# %%
houses1=sales[sales['zipcode']=='98039']

# %%
houses1['price'].mean()
# Out:
# 2160606.5999999996

# %%
houses2 = sales[ (sales['sqft_living']>2000) & (sales['sqft_living']<=4000)]
houses2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 1736800520 | 2015-04-03 00:00:00+00:00 |  662500 |    3     |    2.5    |     3560    |
# | 9297300055 | 2015-01-24 00:00:00+00:00 |  650000 |    4     |     3     |     2950    |
# ...

# %%
len(houses2)/float(len(sales))
# Out:
# 0.42187572294452413

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']
advanced_features =[
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house				
'grade', # measure of quality of construction				
'waterfront', # waterfront property				
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
train_data,test_data = sales.random_split(.8,seed=0)
my_features_model = graphlab.linear_regression.create(train_data,target='price',features=my_features ,validation_set=None)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 17384
# PROGRESS: Number of features          : 6
# PROGRESS: Number of unpacked features : 6
# PROGRESS: Number of coefficients    : 115
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | 1         | 2        | 1.068061     | 3763208.270523     | 181908.848367 |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: SUCCESS: Optimal solution found.
# PROGRESS:

# %%
my_features_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
#
# Rows: 115
#
# Data:
# +-------------+-------+----------------+
# |     name    | index |     value      |
# +-------------+-------+----------------+
# | (intercept) |  None | -88006.8416465 |
# |   bedrooms  |   2   | 21165.5766369  |
# |   bedrooms  |   4   | -41706.3113919 |
# |   bedrooms  |   5   | -92815.3727611 |
# |   bedrooms  |   1   | 45824.7402238  |
# |   bedrooms  |   6   | -179627.840979 |
# |   bedrooms  |   7   | -370367.546312 |
# |   bedrooms  |   8   | -343106.520191 |
# |   bedrooms  |   0   | -13095.4952099 |
# |   bedrooms  |   9   | -432903.521695 |
# +-------------+-------+----------------+
# [115 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
my_features_model.evaluate(test_data)
# Out:
# {'max_error': 3486584.509381705, 'rmse': 179542.4333126903}

# %%
advances_model = graphlab.linear_regression.create(train_data, target='price', features=advanced_features, validation_set=None)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 17384
# PROGRESS: Number of features          : 18
# PROGRESS: Number of unpacked features : 18
# PROGRESS: Number of coefficients    : 127
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | 1         | 2        | 0.032002     | 3469012.450686     | 154580.940736 |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: SUCCESS: Optimal solution found.
# PROGRESS:

# %%
advances_model.evaluate(test_data)
# Out:
# {'max_error': 3556849.413858208, 'rmse': 156831.1168021901}

# %%
179542.4333126903-156831.1168021901
# Out:
# 22711.316510500183
